# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt 
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
from sklearn.preprocessing import PowerTransformer
import scipy.stats as stats
import seaborn as sns

# %%
df = pd.read_csv('concrete_data.csv')

# %%
df.head(2)
# Out:
#    Cement  Blast Furnace Slag  Fly Ash  Water  Superplasticizer  \
# 0   540.0                 0.0      0.0  162.0               2.5
# 1   540.0                 0.0      0.0  162.0               2.5
#
#    Coarse Aggregate  Fine Aggregate  Age  Strength
# 0            1040.0           676.0   28     79.99
# 1            1055.0           676.0   28     61.89

# %%
df.shape
# Out:
# (1030, 9)

# %%
df.isnull().sum()
# Out:
# Cement                0
# Blast Furnace Slag    0
# Fly Ash               0
# Water                 0
# Superplasticizer      0
# Coarse Aggregate      0
# Fine Aggregate        0
# Age                   0
# Strength              0
# dtype: int64

# %%
df.describe() #check the dataset contains any negative or zero values
# Out:
#             Cement  Blast Furnace Slag      Fly Ash        Water  \
# count  1030.000000         1030.000000  1030.000000  1030.000000
# mean    281.167864           73.895825    54.188350   181.567282
# std     104.506364           86.279342    63.997004    21.354219
# min     102.000000            0.000000     0.000000   121.800000
# 25%     192.375000            0.000000     0.000000   164.900000
# 50%     272.900000           22.000000     0.000000   185.000000
# 75%     350.000000          142.950000   118.300000   192.000000
# max     540.000000          359.400000   200.100000   247.000000
#
#        Superplasticizer  Coarse Aggregate  Fine Aggregate          Age  \
# count       1030.000000       1030.000000     1030.000000  1030.000000
# mean           6.204660        972.918932      773.580485    45.662136
# std            5.973841         77.753954       80.175980    63.169912
# min            0.000000        801.000000      594.000000     1.000000
# ...

# %%
x = df.drop(columns=['Strength'])
y = df.iloc[:,-1]

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
linearRegression = LinearRegression()

# %%
linearRegression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = linearRegression.predict(x_test)

# %%
r2_score(y_test,y_pred)
# Out:
# 0.6275531792314848

# %%
lr = LinearRegression()
np.mean(cross_val_score(lr,x,y,scoring='r2'))
#  here I create the object of LinearRegression and the cross_val_score function to 
# check the r2 score using cross validation technique 5 times by default.
# and get the mean of it
# Out:
# np.float64(0.46099404916628683)

# %%
#Plotting the distplots without any transformation
for col in x_train.columns:
    plt.figure(figsize=(14,4))
    plt.subplot(121)
    sns.distplot(x_train[col])
    plt.title(col)
    
    plt.subplot(122)
    stats.probplot(x_train[col],dist="norm",plot=plt)
    plt.title(col)

    plt.show()
# Out:
# C:\Users\rajmu\AppData\Local\Temp\ipykernel_19764\2844013163.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x_train[col])
# C:\Users\rajmu\AppData\Local\Temp\ipykernel_19764\2844013163.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x_train[col])
# ...

# %% [markdown]
# ## Applying the Box-Cox Transformation

# %%
boxCox = PowerTransformer(method='box-cox')

# %%
x_train_boxcox = boxCox.fit_transform(x_train+0.000001)
# x_test_boxcox = boxCox.transform(x_test)

# %%
np.mean(cross_val_score(lr,x_train_boxcox,y_train,scoring='r2'))
# Out:
# np.float64(0.79239766193883)
