# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import OneHotEncoder

# %%
df = pd.read_csv('cars.csv')

# %%
df.head()
# Out:
#      brand  km_driven    fuel         owner  selling_price
# 0   Maruti     145500  Diesel   First Owner         450000
# 1    Skoda     120000  Diesel  Second Owner         370000
# 2    Honda     140000  Petrol   Third Owner         158000
# 3  Hyundai     127000  Diesel   First Owner         225000
# 4   Maruti     120000  Petrol   First Owner         130000

# %%
df['brand'].value_counts()
# Out:
# brand
# Maruti           2448
# Hyundai          1415
# Mahindra          772
# Tata              734
# Toyota            488
# Honda             467
# Ford              397
# Chevrolet         230
# Renault           228
# Volkswagen        186
# BMW               120
# Skoda             105
# Nissan             81
# Jaguar             71
# Volvo              67
# Datsun             65
# Mercedes-Benz      54
# Fiat               47
# Audi               40
# Lexus              34
# Jeep               31
# Mitsubishi         14
# Land                6
# Force               6
# Isuzu               5
# Ambassador          4
# Kia                 4
# MG                  3
# Daewoo              3
# Ashok               1
# Opel                1
# Peugeot             1
# Name: count, dtype: int64

# %%
len(df['brand'].unique())
# Out:
# 32

# %%
df['fuel'].unique()
# Out:
# array(['Diesel', 'Petrol', 'LPG', 'CNG'], dtype=object)

# %%
df['owner'].unique()
# Out:
# array(['First Owner', 'Second Owner', 'Third Owner',
#        'Fourth & Above Owner', 'Test Drive Car'], dtype=object)

# %% [markdown]
# ### One Hot Encoding

# %%
pd.get_dummies(df,columns=['fuel','owner'])
# Out:
#         brand  km_driven  selling_price  fuel_CNG  fuel_Diesel  fuel_LPG  \
# 0      Maruti     145500         450000     False         True     False
# 1       Skoda     120000         370000     False         True     False
# 2       Honda     140000         158000     False        False     False
# 3     Hyundai     127000         225000     False         True     False
# 4      Maruti     120000         130000     False        False     False
# ...       ...        ...            ...       ...          ...       ...
# 8123  Hyundai     110000         320000     False        False     False
# 8124  Hyundai     119000         135000     False         True     False
# 8125   Maruti     120000         382000     False         True     False
# 8126     Tata      25000         290000     False         True     False
# 8127     Tata      25000         290000     False         True     False
#
#       fuel_Petrol  owner_First Owner  owner_Fourth & Above Owner  \
# ...

# %% [markdown]
# ### k-1 One Hot Encoding

# %%
pd.get_dummies(df,columns=['fuel','owner'],drop_first=True)
# Out:
#         brand  km_driven  selling_price  fuel_Diesel  fuel_LPG  fuel_Petrol  \
# 0      Maruti     145500         450000         True     False        False
# 1       Skoda     120000         370000         True     False        False
# 2       Honda     140000         158000        False     False         True
# 3     Hyundai     127000         225000         True     False        False
# 4      Maruti     120000         130000        False     False         True
# ...       ...        ...            ...          ...       ...          ...
# 8123  Hyundai     110000         320000        False     False         True
# 8124  Hyundai     119000         135000         True     False        False
# 8125   Maruti     120000         382000         True     False        False
# 8126     Tata      25000         290000         True     False        False
# 8127     Tata      25000         290000         True     False        False
#
# ...

# %% [markdown]
# #### Show the One Hot Encoding using pandas library but it is not recommended to solve this problem using pandas because it doesn't remember which column it remove while we do the k-1 one hot encoding

# %% [markdown]
# #### That's why we use Scikit-Learn

# %% [markdown]
# ### One Hot Encoding Using Scikit-Learn

# %%
df.sample(2)
# Out:
#         brand  km_driven    fuel         owner  selling_price
# 658    Maruti      69779  Petrol   First Owner         600000
# 5335  Hyundai      74000  Diesel  Second Owner         401000

# %%
x_train,x_test,y_train,y_test = train_test_split(df.iloc[:,:4],df.iloc[:,4],test_size=0.2,random_state=0)

# %%
x_train.shape,x_test.shape
# Out:
# ((6502, 4), (1626, 4))

# %%
onehot_encoder = OneHotEncoder()

# %%
x_train_new = onehot_encoder.fit_transform(x_train[['fuel','owner']])

# %%
np.hstack((x_train[['brand','km_driven']].values,x_train_new.toarray()))
# Out:
# array([['Hyundai', 60000, 0.0, ..., 0.0, 0.0, 0.0],
#        ['Tata', 150000, 0.0, ..., 0.0, 0.0, 1.0],
#        ['Hyundai', 110000, 0.0, ..., 1.0, 0.0, 0.0],
#        ...,
#        ['Hyundai', 90000, 0.0, ..., 1.0, 0.0, 0.0],
#        ['Volkswagen', 90000, 0.0, ..., 0.0, 0.0, 0.0],
#        ['Hyundai', 110000, 0.0, ..., 0.0, 0.0, 0.0]],
#       shape=(6502, 11), dtype=object)

# %% [markdown]
# #### what I am do here actually? -> first I create the object of OneHotEncoder() and then fit transform the x_train data but in x_train I have 4 columns but we have to OneHotEncode with fule and owner column so just fit and transform only the both column and then using the hstack method of numpy which actually horizontally merge two numpy array. Disclamer: we have to convert the fit_transform data to a numpy array and also pick the 'brand' and 'km_driven' from the dataset and using the values property we convert it to the numpy array
